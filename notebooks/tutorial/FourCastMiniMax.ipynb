# %% [markdown]
# # Train and run a simplified global weather model (low hardware and data requirements)
#
# Overview:
# - Downloading training data (takes a few minutes)
# - Training a neural network to predict global weather conditions (takes around 10 minutes per epoch)
# - Inferencing the network on unseen data (takes only a moment)
#
# This demo allows the user to download a 2.8GB file containing around 60 years of global Earth system analysis data. Analysis means the science comnunity's best estimate of historical weather conditions based on available observations. The data set used here was produced by the European Centre for Medium Range Weather Forecasting (ECMWF). This is a standard data set used in the field, however most research is done on a higher-resolution version of the data. That said, there is valuable research done at the lower resolution also. The spatial (latitude and longitude) resolution of this data is 64 pixels by 32 pixels, but the time series is very long. Only a few of the most interesting variables are downloaded in this notebook, for reasons of space.
#
# The data is made available by the ECMWF under license, and the conditions are described here: https://www.ecmwf.int/en/forecasts/accessing-forecasts/licences-available . Please review this before making use of the data for anything. In this tutorial, the data is downloaded using instructions from the weatherbench2 data guide. Please see https://weatherbench2.readthedocs.io/en/latest/data-guide.html for more information on the data, open access, and accessing other resolutions of the data.

# %%
import os

# IMPORTANT! Set this to where you want to store your copy of the data!
# os.environ['ERA5LOWRESDEMO'] = os.path.expanduser("~")  # to use your home directory
# os.environ['ERA5LOWRESDEMO'] = os.path.abspath('./')    # to use the current working directory
# os.environ['ERA5LOWRESDEMO'] = os.environ['PBS_JOBFS']  # to use a job-specific temporary directory
# os.environ['ERA5LOWRESDEMO'] = os.path.abspath('/tmp')  # to use the /tmp directory

os.environ['ERA5LOWRESDEMO'] = os.path.abspath('/scratch/kd24/tjl548/ML/MiniMax')    # use /tmp by default

import hydra
import pathlib
import xarray as xr

from omegaconf import OmegaConf

import pyearthtools.data.archive
import pyearthtools.tutorial
import pyearthtools.training
import pyearthtools.pipeline

import fourcastnext

# import torch; torch.set_default_device(<YOUR_DEVICE_HERE>)  # Uncomment and set this if you need to configure a non-default device.

# %%
workdir = os.environ['ERA5LOWRESDEMO']
print(f'This tutorial will download a copy of the input data to {workdir}. It will also create model checkpoint files and other data here.')

if pyearthtools.data.archive.ROOT_DIRECTORIES['era5lowresdemo'] != workdir:
    print("There is some misconfiguration of your working directory, please review the commented out cells at the start of the notebook")
# Out:
# This tutorial will download a copy of the input data to /scratch/kd24/tjl548/ML/MiniMax. It will also create model checkpoint files and other data here.

# %%
file_location = os.environ['ERA5LOWRESDEMO'] + '/mini.nc'

if not os.path.exists(file_location):
    print("Training data not found, downloading around 2.8GB of data")
    era5_lowres = xr.open_zarr('gs://weatherbench2/datasets/era5/1959-2022-6h-64x32_equiangular_conservative.zarr')
    subset = era5_lowres[['10m_u_component_of_wind', 
                          '10m_v_component_of_wind', 
                          '2m_temperature', 
                          'mean_sea_level_pressure',
                          'geopotential',
                          'toa_incident_solar_radiation_6hr',
                          'temperature']]

    bilevel = subset.sel({'level': [50, 500]})
    
    # IMPORTANT! Put this somewhere sensible, then set the environment variable as indicated at the start of the tutorial
    bilevel.to_netcdf(file_location)
    print("Wrote file to {file_location}")
    assert os.path.exists(file_location)
else:
    print("File already downloaded, skipping ...")
# Out:
# File already downloaded, skipping ...

# %%
accessor = pyearthtools.tutorial.ERA5DataClass.ERA5LowResDemoIndex([
                 '10m_u_component_of_wind', 
                 '10m_v_component_of_wind', 
                 'mean_sea_level_pressure',
                 '2m_temperature'],
filename_override=file_location)

# %%
accessor['2010-01-01']
# Out:
# <xarray.Dataset> Size: 132kB
# Dimensions:                  (time: 4, longitude: 64, latitude: 32)
# Coordinates:
#   * latitude                 (latitude) float64 256B -87.19 -81.56 ... 87.19
#   * longitude                (longitude) float64 512B 0.0 5.625 ... 348.8 354.4
#   * time                     (time) datetime64[ns] 32B 2010-01-01 ... 2010-01...
# Data variables:
#     10m_v_component_of_wind  (time, longitude, latitude) float32 33kB dask.array<chunksize=(4, 36, 18), meta=np.ndarray>
#     10m_u_component_of_wind  (time, longitude, latitude) float32 33kB dask.array<chunksize=(4, 36, 18), meta=np.ndarray>
#     2m_temperature           (time, longitude, latitude) float32 33kB dask.array<chunksize=(4, 36, 18), meta=np.ndarray>
#     mean_sea_level_pressure  (time, longitude, latitude) float32 33kB dask.array<chunksize=(4, 36, 18), meta=np.ndarray>

# %%
data_pipeline = pyearthtools.pipeline.Pipeline(
    accessor,
    pyearthtools.data.transforms.coordinates.StandardLongitude(type="0-360"),
    # pyearthtools.pipeline.operations.xarray.reshape.CoordinateFlatten("level"),
    pyearthtools.pipeline.modifications.TemporalRetrieval(
        concat=True, samples=((-6, 1), (6, 2, 6))
    ),
    pyearthtools.pipeline.operations.xarray.conversion.ToNumpy(),
    pyearthtools.pipeline.operations.numpy.reshape.Rearrange('c t h w -> t c h w'),    
    sampler=pyearthtools.pipeline.samplers.Default(),
    iterator=pyearthtools.pipeline.iterators.DateRange(1980, 2016, interval='6 hours')
)
# data_pipeline

# %%
# data_pipeline['2010-01-01']

# %%
splits = {
    'train_split': pyearthtools.pipeline.iterators.DateRange(1980, 2016, interval='6 hours'),
    'valid_split': pyearthtools.pipeline.iterators.DateRange(2018, 2020, interval = '6 hours'),
}

# If you encounter memory problems, set the batch size to a lower number, or 1
# If you encounter CPU / multithreading issues, set num_workers to a lower number, or 0
# 0 is a special number which means 'use the main process', whereas '1' will spawn 1 worker
datamodule = pyearthtools.training.data.lightning.PipelineLightningDataModule(
    data_pipeline,
    **splits,
    **{'num_workers': 0, 'batch_size': 4}
)

# %%
# If this model doesn't fit on your GPU, reduce the size of the embed_dim to a much lower
# number. This will impact model accuracy but may still produce acceptable outputs.
model = fourcastnext.registered_model.FourCastNextRM(
    pipeline=data_pipeline,       
    lightning_model_params = {'img_size': (64, 32), 
                              'in_channels': 4, 
                              'out_channels': 4,
                              'embed_dim': 768,
                              'depth': 12,
                             },
    output='.',
    lead_time=24
)

# %%
checkpoint_path = os.environ['ERA5LOWRESDEMO']

# %%
trainer_configuration = {'precision': '16-mixed',                          
                         'checkpointing': [
                             {'monitor': 'train_loss', 'mode': 'min', 
                              'dirpath': '{path}/Checkpoints/Train', 
                              'filename': 'model-{epoch:02d}-{step:02d}', 
                              'every_n_train_steps': 1000, 'save_top_k': 10}, 
                             {'monitor': 'valid_loss', 'mode': 'min', 
                              'dirpath': '{path}/Checkpoints/Valid', 
                              'filename': 'model-{epoch:02d}-{step:02d}-{valid_loss}', 
                              'every_n_train_steps': 5000, 'save_top_k': 10}, 
                             {'monitor': 'epoch', 'mode': 'max', 
                              'dirpath': '{path}/Checkpoints/Epoch', 
                              'filename': 'model-{epoch:02d}', 
                              'save_on_train_epoch_end': True, 
                              'save_top_k': 50}]}

checkpoint_path = os.environ['ERA5LOWRESDEMO']

# %%
# For a fully converged model, set the max epochs to a much larger number, like
# 40 or even 200.

MAX_EPOCHS = 10

trainer = pyearthtools.training.lightning.Train(
    model.lightning_model,
    datamodule,
    path=checkpoint_path,
    trainer_kwargs={'num_sanity_val_steps': 1, 'max_epochs': MAX_EPOCHS, },
    **trainer_configuration
)

# %%
trainer.fit()
# Out:
# /g/data/kd24/tjl/src/PyEarthTools/packages/training/src/pyearthtools/training/wrapper/lightning/wrapper.py:121: Loading checkpoint: /scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=00-step=11000.ckpt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:654: Checkpoint directory /scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train exists and is not empty.
# Restoring states from the checkpoint path at /scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=00-step=11000.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type    | Params | Mode
# ---------------------------------------------
# 0 | model    | AFNONet | 60.6 M | train
# 1 | loss_obj | L1Loss  | 0      | train
# ---------------------------------------------
# 60.6 M    Trainable params
# 0         Non-trainable params
# 60.6 M    Total params
# 242.310   Total estimated model params size (MB)
# 104       Modules in train mode
# 0         Modules in eval mode
# Restored all states from the checkpoint at /scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=00-step=11000.ckpt
# /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py:221: You're resuming from a checkpoint that ended before the epoch ended and your dataloader is not resumable. This can cause unreliable results if further training is done. Consider using an end-of-epoch checkpoint or make your dataloader resumable by implementing the `state_dict` / `load_state_dict` interface.
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:599, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     593 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     594     self.state.fn,
#     595     ckpt_path,
#     596     model_provided=True,
#     597     model_connected=self.lightning_module is not None,
#     598 )
# --> 599 self._run(model, ckpt_path=ckpt_path)
#     601 assert self.state.stopped
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:1012, in Trainer._run(self, model, ckpt_path)
#    1009 # ----------------------------
#    1010 # RUN THE TRAINER
#    1011 # ----------------------------
# -> 1012 results = self._run_stage()
#    1014 # ----------------------------
#    1015 # POST-Training CLEAN UP
#    1016 # ----------------------------
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:1056, in Trainer._run_stage(self)
#    1055 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1056     self.fit_loop.run()
#    1057 return None
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py:216, in _FitLoop.run(self)
#     215 self.on_advance_start()
# --> 216 self.advance()
#     217 self.on_advance_end()
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/fit_loop.py:455, in _FitLoop.advance(self)
#     454 assert self._data_fetcher is not None
# --> 455 self.epoch_loop.run(self._data_fetcher)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py:150, in _TrainingEpochLoop.run(self, data_fetcher)
#     149 try:
# --> 150     self.advance(data_fetcher)
#     151     self.on_advance_end(data_fetcher)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/training_epoch_loop.py:282, in _TrainingEpochLoop.advance(self, data_fetcher)
#     281 dataloader_iter = None
# --> 282 batch, _, __ = next(data_fetcher)
#     283 # TODO: we should instead use the batch_idx returned by the fetcher, however, that will require saving the
#     284 # fetcher state so that the batch_idx is correct after restarting
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/fetchers.py:134, in _PrefetchDataFetcher.__next__(self)
#     132 elif not self.done:
#     133     # this will run only when no pre-fetching was done.
# --> 134     batch = super().__next__()
#     135 else:
#     136     # the iterator is empty
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/loops/fetchers.py:61, in _DataFetcher.__next__(self)
#      60 try:
# ---> 61     batch = next(self.iterator)
#      62 except StopIteration:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/utilities/combined_loader.py:341, in CombinedLoader.__next__(self)
#     340 assert self._iterator is not None
# --> 341 out = next(self._iterator)
#     342 if isinstance(self._iterator, _Sequential):
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/utilities/combined_loader.py:78, in _MaxSizeCycle.__next__(self)
#      77 try:
# ---> 78     out[i] = next(self.iterators[i])
#      79 except StopIteration:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/torch/utils/data/dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/torch/utils/data/dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     788 index = self._next_index()  # may raise StopIteration
# --> 789 data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790 if self._pin_memory:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/training/src/pyearthtools/training/data/lightning/datasets.py:90, in PytorchDataset.__getitem__(self, idx)
#      89 def __getitem__(self, idx):
# ---> 90     return self._pipeline[self._pipeline.iteration_order[idx]]
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/controller.py:492, in Pipeline.__getitem__(self, idx)
#     490     return map(self.__getitem__, indexes)
# --> 492 sample, step_index = self._get_initial_sample(idx)
#     493 LOG.debug(f"Call pipeline __getitem__ for {idx = }")
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/controller.py:476, in Pipeline._get_initial_sample(self, idx)
#     475         LOG.debug(f"Getting initial sample from {step} at {idx}")
# --> 476         return step[idx], len(self.steps) - (index + 1)
#     478 # Confirm that the start of the pipeline is an accessor, and then fetch from it
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/modifications/idx_modification.py:472, in TemporalRetrieval.__getitem__(self, idx)
#     470     idx = pyearthtools.data.Petdt(idx)
# --> 472 return super().__getitem__(idx)
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/modifications/idx_modification.py:434, in SequenceRetrieval.__getitem__(self, idx)
#     433 def __getitem__(self, idx: Any):
# --> 434     return super().__getitem__(idx)
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/modifications/idx_modification.py:226, in IdxModifier.__getitem__(self, idx)
#     224     return self.parent_pipeline()[idx + self._modification]
# --> 226 return self._get_tuple(idx, self._modification, 0)
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/modifications/idx_modification.py:206, in IdxModifier._get_tuple(self, idx, mod, layer)
#     205 if isinstance(m, tuple):
# --> 206     samples.append(self.parallel_interface.submit(self._get_tuple, idx, m, layer + 1))
#     207 else:
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/parallel.py:128, in SerialInterface.submit(self, func, *args, **kwargs)
#     127 def submit(self, func, *args, **kwargs):
# --> 128     return FutureFaker(func(*args, **kwargs))
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/modifications/idx_modification.py:208, in IdxModifier._get_tuple(self, idx, mod, layer)
#     207     else:
# --> 208         samples.append(self.parallel_interface.submit(super_get, idx + m))
#     210 samples = tuple(self.parallel_interface.collect(samples))
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/parallel.py:128, in SerialInterface.submit(self, func, *args, **kwargs)
#     127 def submit(self, func, *args, **kwargs):
# --> 128     return FutureFaker(func(*args, **kwargs))
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/controller.py:492, in Pipeline.__getitem__(self, idx)
#     490     return map(self.__getitem__, indexes)
# --> 492 sample, step_index = self._get_initial_sample(idx)
#     493 LOG.debug(f"Call pipeline __getitem__ for {idx = }")
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/pipeline/src/pyearthtools/pipeline/controller.py:481, in Pipeline._get_initial_sample(self, idx)
#     480     LOG.debug(f"Getting initial sample from {self.steps[0]} at {idx}")
# --> 481     return self.steps[0][idx], 0
#     483 raise TypeError(f"Cannot find an `Index` to get data from. Found {type(self.steps[0]).__qualname__}")
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/data/src/pyearthtools/data/indexes/utilities/mixins/call_redirect.py:42, in CallRedirectMixin.__getitem__(self, idx)
#      41 """[] accessor"""
# ---> 42 return self.__call__(idx)
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/data/src/pyearthtools/data/indexes/indexes.py:923, in AdvancedTimeIndex.__call__(self, *args, **kwargs)
#     922 if len(args) == 1:
# --> 923     return self.retrieve(*args, **kwargs)
#     925 return self.series(*args, **kwargs)
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/tutorial/src/pyearthtools/tutorial/ERA5DataClass.py:321, in ERA5LowResDemoIndex.retrieve(self, transforms, *args, **kwargs)
#     320 # kwargs.update(self._get_preprocess(kwargs.pop("preprocess", None)))  # type: ignore
# --> 321 return transforms(super().retrieve(*args, **kwargs))
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/data/src/pyearthtools/data/indexes/indexes.py:818, in AdvancedTimeIndex.retrieve(self, querytime, aggregation, select, use_simple, **kwargs)
#     817 elif querytime.resolution == self.data_resolution:  # Equal Resolution
# --> 818     data = super().retrieve(querytime, select=select, **kwargs)
#     819     return data
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/data/src/pyearthtools/data/indexes/indexes.py:701, in SingleTimeDataIndex.retrieve(self, transforms, *args, **kwargs)
#     698 with ChangeValue(self, "_skip_transforms", True):
#     699     # Skip transforms, so that they are only applied once
#     700     # By applying transforms after time retrieve, prevents more then necessary data going to transforms
# --> 701     return transforms(super().retrieve(*args, **kwargs))
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/data/src/pyearthtools/data/indexes/indexes.py:498, in SingleTimeIndex.retrieve(self, querytime, select, round, *args, **kwargs)
#     497 if time_dim not in data.dims and time_dim in data.coords:
# --> 498     data = data.expand_dims(time_dim)
#     500 return data
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/dataset.py:4546, in Dataset.expand_dims(self, dim, axis, create_index_for_new_dim, **dim_kwargs)
#    4545             all_dims.insert(d, c)
# -> 4546         variables[k] = v.set_dims(dict(all_dims))
#    4547 else:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/util/deprecation_helpers.py:143, in deprecate_dims.<locals>.wrapper(*args, **kwargs)
#     142     kwargs["dim"] = kwargs.pop(old_name)
# --> 143 return func(*args, **kwargs)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/variable.py:1377, in Variable.set_dims(self, dim, shape)
#    1376     tmp_shape = tuple(dims_map[d] for d in expanded_dims)
# -> 1377     expanded_data = duck_array_ops.broadcast_to(self._data, tmp_shape)
#    1378 else:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:288, in broadcast_to(array, shape)
#     287 xp = get_array_namespace(array)
# --> 288 return xp.broadcast_to(array, shape)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/numpy/lib/_stride_tricks_impl.py:410, in broadcast_to(array, shape, subok)
#     369 """Broadcast an array to a new shape.
#     370
#     371 Parameters
#    (...)    408        [1, 2, 3]])
#     409 """
# --> 410 return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/numpy/lib/_stride_tricks_impl.py:342, in _broadcast_to(array, shape, subok, readonly)
#     341 shape = tuple(shape) if np.iterable(shape) else (shape,)
# --> 342 array = np.array(array, copy=None, subok=subok)
#     343 if not shape and array.shape:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:511, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     510 if Version(np.__version__) >= Version("2.0.0"):
# --> 511     return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     512 else:
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:837, in MemoryCachedArray.get_duck_array(self)
#     836 def get_duck_array(self):
# --> 837     self._ensure_cached()
#     838     return self.array.get_duck_array()
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:834, in MemoryCachedArray._ensure_cached(self)
#     833 def _ensure_cached(self):
# --> 834     self.array = as_indexable(self.array.get_duck_array())
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:791, in CopyOnWriteArray.get_duck_array(self)
#     790 def get_duck_array(self):
# --> 791     return self.array.get_duck_array()
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:654, in LazilyIndexedArray.get_duck_array(self)
#     651 else:
#     652     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     653     # it may wrap a BackendArray so use its __getitem__
# --> 654     array = self.array[self.key]
#     656 # self.array[self.key] is now a numpy array when
#     657 # self.array is a BackendArray subclass
#     658 # and self.key is BasicIndexer((slice(None, None, None),))
#     659 # so we need the explicit check for ExplicitlyIndexed
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/backends/h5netcdf_.py:55, in H5NetCDFArrayWrapper.__getitem__(self, key)
#      54 def __getitem__(self, key):
# ---> 55     return indexing.explicit_indexing_adapter(
#      56         key, self.shape, indexing.IndexingSupport.OUTER_1VECTOR, self._getitem
#      57     )
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/core/indexing.py:1015, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1014 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1015 result = raw_indexing_method(raw_key.tuple)
#    1016 if numpy_indices.tuple:
#    1017     # index the loaded duck array
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/xarray/backends/h5netcdf_.py:62, in H5NetCDFArrayWrapper._getitem(self, key)
#      61 array = self.get_array(needs_lock=False)
# ---> 62 return array[key]
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/h5netcdf/core.py:553, in BaseVariable.__getitem__(self, key)
#     550     h5ds = self._h5ds
#     552 if (
# --> 553     isinstance(self.datatype, CompoundType)
#     554     and (view := self.datatype.dtype_view) is not None
#     555 ):
#     556     return h5ds[key].view(view)
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/h5netcdf/core.py:482, in BaseVariable.datatype(self)
#     481             return tid
# --> 482 return self.dtype
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/h5netcdf/core.py:139, in BaseObject.dtype(self)
#     138 """Return NumPy dtype giving object’s dtype."""
# --> 139 return self._h5ds.dtype
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/h5netcdf/core.py:129, in BaseObject._h5ds(self)
#     125 @property
#     126 def _h5ds(self):
#     127     # Always refer to the root file and store not h5py object
#     128     # subclasses:
# --> 129     return self._root._h5file[self._h5path]
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:257, in h5py.h5o.open()
#
# File h5py/h5i.pyx:44, in h5py.h5i.wrap_identifier()
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 trainer.fit()
#
# File /g/data/kd24/tjl/src/PyEarthTools/packages/training/src/pyearthtools/training/wrapper/lightning/train.py:169, in LightingTraining.fit(self, load, **kwargs)
#     166 if hasattr(self, "_loaded_file") and self._loaded_file is not None:
#     167     kwargs["ckpt_path"] = str(self._loaded_file)
# --> 169 self.trainer.fit(
#     170     model=self.model,
#     171     **data_config,
#     172     **kwargs,
#     173 )
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/trainer.py:561, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     559 self.training = True
#     560 self.should_stop = False
# --> 561 call._call_and_handle_interrupt(
#     562     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     563 )
#
# File /opt/conda/envs/pet/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:65, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63     if isinstance(launcher, _SubprocessScriptLauncher):
#      64         launcher.kill(_get_sigkill_signal())
# ---> 65     exit(1)
#      67 except BaseException as exception:
#      68     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
# IMPORTANT! Your checkpoints will be in a unique location based on your training!
# full_checkpoint_path = '/scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=00-step=52000.ckpt'
full_checkpoint_path = '/scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=03-step=45000.ckpt'

# %%
data_pipeline = pyearthtools.pipeline.Pipeline(
    accessor,
    pyearthtools.data.transforms.coordinates.StandardLongitude(type="0-360"),
    # pyearthtools.pipeline.operations.xarray.reshape.CoordinateFlatten("level"),
    pyearthtools.pipeline.modifications.TemporalRetrieval(
        concat=True, samples=((-6, 1), (6, 2, 6))
    ),
    pyearthtools.pipeline.operations.xarray.conversion.ToNumpy(),
    pyearthtools.pipeline.operations.numpy.reshape.Rearrange('c t h w -> t c h w'),    
    sampler=pyearthtools.pipeline.samplers.Default(),
    iterator=pyearthtools.pipeline.iterators.DateRange(1980, 2016, interval='6 hours')
)

# %%
pmodel = fourcastnext.registered_model.FourCastNextRM(
    pipeline=data_pipeline,    
    ckpt_path = full_checkpoint_path,
    lightning_model_params = {'img_size': (64, 32), 
                              'in_channels': 4, 
                              'out_channels': 4,
                              'embed_dim': 768,
                              'depth': 12,
                             },
    output='.',
    lead_time=240
)

# %%
# IMPORTANT! This cell must be run to produce prediction data. It produces a lot of debugging information, so it has been commented out for display purposes.
prediction = pmodel.run('2011-01-01T00')
# Out:
# /g/data/kd24/tjl/src/PyEarthTools/packages/training/src/pyearthtools/training/wrapper/lightning/wrapper.py:121: Loading checkpoint: /scratch/kd24/tjl548/ML/MiniMax/Checkpoints/Train/model-epoch=00-step=10000.ckpt
# Predicting Autorecurrently:   0%|          | 0/40 [00:00<?, ?it/s]
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /g/data/kd24/tjl/src/PyEarthTools/packages/utils/src/pyearthtools/utils/data/converter.py:317: RuntimeWarning: Incoming and expected shape don't match. (4, 40, 64, 32) != (4, 1, 64, 32). Dropping conflicting coordinates.
#   warnings.warn(

# %%
data_pipeline = pyearthtools.pipeline.Pipeline(
    pyearthtools.data.archive.era5_demo_subset(['msl', '10u', '10v', '2t']),
    pyearthtools.data.transforms.coordinates.StandardLongitude(type="-180-180"),
    fourcastnext.CropToRectangleSmall(),
    pyearthtools.pipeline.modifications.TemporalRetrieval(
        concat=True,
        samples = ((-6, 1), (6, 2, 6))
    ),
)

# %%
# Plot prediction
LEAD_INTERVAL = 4 # (each interval is an additional 6 hours)
(prediction['2m_temperature'][LEAD_INTERVAL] - 273.15).plot(x='longitude', y='latitude')

# %%
# Plot observation
(data_pipeline['2011-01-02T12'][0]['2m_temperature']- 273.15).plot(x='longitude', y='latitude')

# %% [markdown]
# # Things to try next
#
# 1. This model uses a simple crop to fit the kernel size expected by FourCastNeXt. It would be better to regrid it to the right size.
# 2. The model needs to train for quite a while to converge. A common problem in machine learning is not knowing quite how long to train a network. Try training it on more data, or for more epochs, and chart out how that affects the training effectiveness as measured by the loss function
# 3. This notebook doesn't include any comparisons to benchmarks such as a persistence model or an alternative model. Charting skill score comparisons would be very useful.
# 4. A scorecard of results can also be informative, to see accuracy from multiple perspectives
# 5. Charting the skill of the model with respect to lead time would also be a useful exercise
