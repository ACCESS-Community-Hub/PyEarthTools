# %% [markdown]
# # Tutorial Gallery

# %% [markdown]
# ## PyEarthTools - Data Module

# %% [markdown]
# - [Basic Data Indexing](./data/1-Basic_Indexing.ipynb)
# - [Retrieving Single Samples](./data/2-GettingTheMostOfSingle.ipynb)
# - [Complex Time Series Retrieval](./data/3-GettingComplexSeries.ipynb)
# - [Using Built-In Operations](./data/4-UsingTheInBuiltOperations.ipynb)
# - [Applying Data Transforms](./data/5-Transforms.ipynb)
# - [Region Cutting](./data/6-RegionCutting.ipynb)
# - [Custom Data Index](./data/7-CustomDataIndex.ipynb)
# - [The Data Catalog](./data/8-Catalog.ipynb)
# - [Pattern Indexing](./data/9-PatternIndexing.ipynb)

# %% [markdown]
# ## PyEarthTools - Tutorial Examples

# %% [markdown]
# - [NCI Data Access](./tutorial/1a_Interfacing_to_Data_at_NCI.ipynb)
# - [Own Data Example](./tutorial/1b_Interfacing_to_Your_Own_Archive.ipynb)
# - [Introduction to Pipelines](./tutorial/2_Data_Pipelines.ipynb)
# - [End-to-end CNN Training Example](./tutorial/3_CNN_model_training.ipynb)
